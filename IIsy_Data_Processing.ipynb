# %% [markdown]
# <a href="https://colab.research.google.com/github/tylerliu/p4-mininet-test/blob/master/IIsy_Data_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download IIsy repo

# %%
# %cd /content
# !git clone https://github.com/cucl-srg/IIsy
# Out:
# /content
# Cloning into 'IIsy'...
# remote: Enumerating objects: 59, done.
# remote: Total 59 (delta 0), reused 0 (delta 0), pack-reused 59
# Unpacking objects: 100% (59/59), done.

# %% [markdown]
# # Download/unzip cap data

# %%
# !mkdir IIsy/trace_processing/original_files
# !mkdir IIsy/trace_processing/csv_files
# %cd /content/IIsy/trace_processing/original_files
# !wget --no-check-certificate  https://iotanalytics.unsw.edu.au/iottestbed/pcap/filelist.txt
# !cat filelist.txt | egrep -v "(^#.*|^$)" | xargs -n 1 wget --no-check-certificate
# Out:
# /content/IIsy/trace_processing/original_files
# --2021-05-31 19:55:40--  https://iotanalytics.unsw.edu.au/iottestbed/pcap/filelist.txt
# Resolving iotanalytics.unsw.edu.au (iotanalytics.unsw.edu.au)... 149.171.189.1
# Connecting to iotanalytics.unsw.edu.au (iotanalytics.unsw.edu.au)|149.171.189.1|:443... connected.
# WARNING: cannot verify iotanalytics.unsw.edu.au's certificate, issued by ‘CN=QuoVadis Global SSL ICA G3,O=QuoVadis Limited,C=BM’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 3964 (3.9K) [text/plain]
# Saving to: ‘filelist.txt’
#
# filelist.txt        100%[===================>]   3.87K  --.-KB/s    in 0s
#
# 2021-05-31 19:55:41 (279 MB/s) - ‘filelist.txt’ saved [3964/3964]
#
# --2021-05-31 19:55:41--  https://iotanalytics.unsw.edu.au/iottestbed/pcap/16-09-23.tar.gz
# Resolving iotanalytics.unsw.edu.au (iotanalytics.unsw.edu.au)... 149.171.189.1
# ...

# %%
# %cd /content/IIsy/trace_processing/original_files
# !ls | grep '.tar.gz' | xargs -n 1 tar -xzvf
# Out:
# /content/IIsy/trace_processing/original_files
# 16-09-23.pcap
# 16-09-24.pcap
# 16-09-25.pcap
# 16-09-26.pcap
# 16-09-27.pcap
# 16-09-28.pcap
# 16-09-29.pcap
# 16-09-30.pcap
# 16-10-01.pcap
# 16-10-02.pcap
# 16-10-03.pcap
# 16-10-04.pcap
# 16-10-05.pcap
# 16-10-06.pcap
# 16-10-07.pcap
# 16-10-08.pcap
# 16-10-09.pcap
# 16-10-10.pcap
# 16-10-11.pcap
# 16-10-12.pcap
# 16-10-13.pcap
# 16-10-14.pcap
# 16-10-15.pcap
# 16-10-16.pcap
# 16-10-17.pcap
# 16-10-18.pcap
# 16-10-19.pcap
# 16-10-20.pcap
# 16-10-21.pcap
# 16-10-22.pcap
# 16-10-23.pcap
# 16-10-24.pcap
# 16-10-25.pcap
# 16-10-26.pcap
# 16-10-27.pcap
# 16-10-28.pcap
# 16-10-29.pcap
# 16-10-30.pcap
# 16-10-31.pcap
# 16-11-01.pcap
# 16-11-02.pcap
# 16-11-04.pcap
# 16-11-05.pcap
# 16-11-06.pcap
# 16-11-07.pcap
# 16-11-08.pcap
# 16-11-09.pcap
# 16-11-10.pcap
# 16-11-11.pcap
# 16-11-12.pcap
# 16-11-13.pcap
# 16-11-14.pcap
# ./16-11-15.pcap
# 16-11-16.pcap
# 16-11-17.pcap
# 16-11-18.pcap
# 16-11-19.pcap
# 16-11-20.pcap
# 16-11-21.pcap
# ...

# %%
# %cd /content/IIsy/trace_processing/original_files
# !rm *.tar.gz filelist.txt
# Out:
# /content/IIsy/trace_processing/original_files
# rm: cannot remove '*.tar.gz': No such file or directory
# rm: cannot remove 'filelist.txt': No such file or directory

# %% [markdown]
# # Process Pcap

# %%
# !apt-get update
# !apt-get install tshark
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# ...

# %%
# %cd /content/IIsy/trace_processing
# !bash ./set_features.sh replacement_numeric
# Out:
# /content/IIsy/trace_processing
# Usage: ./set_features.py <substitution file>
# original_files/16-11-06.pcap
# rm: cannot remove 'tmp': No such file or directory
# Running as user "root" and group "root". This could be dangerous.
# original_files/16-10-25.pcap
# rm: cannot remove 'tmp': No such file or directory
# Running as user "root" and group "root". This could be dangerous.
# original_files/16-11-04.pcap
# rm: cannot remove 'tmp': No such file or directory
# Running as user "root" and group "root". This could be dangerous.
# original_files/16-11-20.pcap
# rm: cannot remove 'tmp': No such file or directory
# Running as user "root" and group "root". This could be dangerous.
#
# ** (process:3565): WARNING **: 20:41:48.934: Dissector bug, protocol HTTP, in packet 475402: /build/wireshark-DSKWzx/wireshark-2.6.10/epan/packet.c:757: failed assertion "saved_layers_len < 500"
#
# ...

# %%
# %cd /content/IIsy/trace_processing/csv_files
# !head -10 *labeled.csv
# Out:
# /content/IIsy/trace_processing/csv_files
# ==> 16-09-23-labeled.csv <==
# 74,0x00000800,6,0x00004000,-1,-1,4425,49153,0x00000002,-1,-1,0
# 66,0x00000800,6,0x00004000,-1,-1,4425,49153,0x00000010,-1,-1,0
# 262,0x00000800,6,0x00004000,-1,-1,4425,49153,0x00000018,-1,-1,0
# 66,0x00000800,6,0x00004000,-1,-1,4425,49153,0x00000010,-1,-1,0
# 66,0x00000800,6,0x00004000,-1,-1,4425,49153,0x00000011,-1,-1,0
# 74,0x00000800,6,0x00004000,-1,-1,4426,49153,0x00000002,-1,-1,0
# 66,0x00000800,6,0x00004000,-1,-1,4426,49153,0x00000010,-1,-1,0
# 264,0x00000800,6,0x00004000,-1,-1,4426,49153,0x00000018,-1,-1,0
# 66,0x00000800,6,0x00004000,-1,-1,4426,49153,0x00000010,-1,-1,0
# 66,0x00000800,6,0x00004000,-1,-1,4426,49153,0x00000011,-1,-1,0
#
# ==> 16-09-24-labeled.csv <==
# 118,0x00000800,1,0x00004000,-1,-1,-1,-1,-1,-1,-1,0
# 118,0x00000800,1,0x00004000,-1,-1,-1,-1,-1,-1,-1,0
# 118,0x00000800,1,0x00004000,-1,-1,-1,-1,-1,-1,-1,0
# 42,0x00000806,-1,-1,-1,-1,-1,-1,-1,-1,-1,0
# ...

# %% [markdown]
# # CSV export

# %%
# %cd /content/IIsy/trace_processing
# !tar -czvf csv_files.tar.gz csv_files
# Out:
# /content/IIsy/trace_processing
# csv_files/
# csv_files/16-11-06-labeled.csv
# csv_files/16-11-17-labeled.csv
# csv_files/16-11-09-labeled.csv
# csv_files/16-10-24-labeled.csv
# csv_files/16-11-20-labeled.csv
# csv_files/16-10-09-labeled.csv
# csv_files/16-11-01-labeled.csv
# csv_files/16-11-05-labeled.csv
# csv_files/16-10-30-labeled.csv
# csv_files/16-10-31-labeled.csv
# csv_files/16-11-22-labeled.csv
# csv_files/16-10-19-labeled.csv
# csv_files/16-10-26-labeled.csv
# csv_files/16-10-15-labeled.csv
# csv_files/16-11-12-labeled.csv
# csv_files/16-10-08-labeled.csv
# csv_files/16-10-22-labeled.csv
# csv_files/16-10-13-labeled.csv
# csv_files/16-10-05-labeled.csv
# csv_files/16-10-29-labeled.csv
# csv_files/16-10-01-labeled.csv
# csv_files/16-10-03-labeled.csv
# csv_files/16-09-23-labeled.csv
# csv_files/16-10-12-labeled.csv
# csv_files/16-10-27-labeled.csv
# csv_files/16-10-25-labeled.csv
# csv_files/16-09-24-labeled.csv
# csv_files/16-09-27-labeled.csv
# ...

# %%
# %cd /content/IIsy/trace_processing
# !du -sh *
# Out:
# /content/IIsy/trace_processing
# 3.7G	csv_files
# 94M	csv_files.tar.gz
# 91M	else.csv
# 28G	original_files
# 4.0K	README.md
# 4.0K	replacement_numeric
# 4.0K	set_features.sh

# %% [markdown]
# # training

# %%
# %cd /content/IIsy/iisy_sw/IoT_ML
# !python3 iot_decisiontree.py -i ../../trace_processing/csv_files/16-09-23-labeled.csv -t ../../trace_processing/csv_files/16-09-24-labeled.csv -o a.txt
# Out:
# /content/IIsy/iisy_sw/IoT_ML
# Traceback (most recent call last):
#   File "iot_decisiontree.py", line 134, in <module>
#     dt.fit(X, Y)
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py", line 877, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py", line 149, in fit
#     X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py", line 531, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: '0x00000800'
